# %%
import pandas as pd

# %%
df1_dummy = {
    "serial_id" : ["1", "2" , "3","4","5"],
    "sale_month" : ["Jan","Feb","Mar","Apr","May"],
    "sales" : ["12300","25100", "17000", "20100", "21000"]
}

# %%
df1 = pd.DataFrame(df1_dummy, columns = ["serial_id", "sale_month", "sales"])

df1
# Out:
#   serial_id sale_month  sales
# 0         1        Jan  12300
# 1         2        Feb  25100
# 2         3        Mar  17000
# 3         4        Apr  20100
# 4         5        May  21000

# %%
df2_dummy = {
    "serial_id" : ["6", "7" , "8","9","10"],
    "sale_month" : ["Jun","Jul","Aug","Sep","Oct"],
    "sales" : ["25000","23700", "24600", "24000", "23950"]
}

# %%
df2 = pd.DataFrame(df2_dummy, columns = ["serial_id", "sale_month", "sales"])

df2
# Out:
#   serial_id sale_month  sales
# 0         6        Jun  25000
# 1         7        Jul  23700
# 2         8        Aug  24600
# 3         9        Sep  24000
# 4        10        Oct  23950

# %%
df3_dummy = {
    "sales_threshold" : ["No", "Yes" , "No","Yes","Yes","Yes","No","Yes","Yes","Yes"],
    "bonus_threshold" : ["No", "Yes" , "No","No","Yes","Yes","No","Yes","Yes","No"]
}

# %%
df3 = pd.DataFrame(df3_dummy, columns = ["sales_threshold", "bonus_threshold"])

df3
# Out:
#   sales_threshold bonus_threshold
# 0              No              No
# 1             Yes             Yes
# 2              No              No
# 3             Yes              No
# 4             Yes             Yes
# 5             Yes             Yes
# 6              No              No
# 7             Yes             Yes
# 8             Yes             Yes
# 9             Yes              No

# %%
df_row = pd.concat([df1, df2], ignore_index=True)

df_row
# Out:
#   serial_id sale_month  sales
# 0         1        Jan  12300
# 1         2        Feb  25100
# 2         3        Mar  17000
# 3         4        Apr  20100
# 4         5        May  21000
# 5         6        Jun  25000
# 6         7        Jul  23700
# 7         8        Aug  24600
# 8         9        Sep  24000
# 9        10        Oct  23950

# %%
df_full = pd.concat([df_row, df3], axis=1)

df_full
# Out:
#   serial_id sale_month  sales sales_threshold bonus_threshold
# 0         1        Jan  12300              No              No
# 1         2        Feb  25100             Yes             Yes
# 2         3        Mar  17000              No              No
# 3         4        Apr  20100             Yes              No
# 4         5        May  21000             Yes             Yes
# 5         6        Jun  25000             Yes             Yes
# 6         7        Jul  23700              No              No
# 7         8        Aug  24600             Yes             Yes
# 8         9        Sep  24000             Yes             Yes
# 9        10        Oct  23950             Yes              No
